# %%
import pandas as pd
import netCDF4 as nc
import xarray as xr
import matplotlib.pyplot as plt

# %%
dset = netCDF4.Dataset('saida.nc')
dset.variables
# Out:
# {'time': <class 'netCDF4._netCDF4.Variable'>
#  float64 time(time)
#      long_name: time since the beginning of the simulation
#      standard_name: time
#      calendar: gregorian
#      comment: unspecified time zone
#      units: seconds since 2017-07-01T12:00:00
#  unlimited dimensions: time
#  current shape = (721,)
#  filling on, default _FillValue of 9.969209968386869e+36 used,
#  'particle_count': <class 'netCDF4._netCDF4.Variable'>
#  int32 particle_count(time)
#      units: 1
#      long_name: number of particles in a given timestep
#      ragged_row_count: particle count at nth timestep
#  unlimited dimensions: time
#  current shape = (721,)
#  filling on, default _FillValue of -2147483647 used,
#  'evap_decay_constant': <class 'netCDF4._netCDF4.Variable'>
#  float64 evap_decay_constant(data, weathering)
#  unlimited dimensions: data
#  current shape = (360160, 14)
#  filling on, default _FillValue of 9.969209968386869e+36 used,
# ...

# %%
#frac_evap,frac_water,mass,status_code, oil_viscosity, oil_density, density, viscosity

# %%
DS=xr.open_dataset ('saida.nc')
DS['frac_evap'].to_dataframe().to_csv('nova_saida.csv')

# %%
DS=xr.open_dataset ('saida.nc')
DS['frac_water'].to_dataframe().to_csv('nova_saidaWATER.csv')

# %%
DS=xr.open_dataset ('saida.nc')
DS['mass'].to_dataframe().to_csv('nova_saidaMASS.csv')

# %%
DS=xr.open_dataset ('saida.nc')
DS['time'].to_dataframe().to_csv('nova_saidaTIME.csv')
